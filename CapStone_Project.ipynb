# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\tarun\Downloads\CapStone Project\employee_attrition_data.csv', sep=',')

display(df.head())
print(df.columns)
df.info()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df.isna()
df.isna().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
df.duplicated()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]>

# %%
df.drop(columns = 'Employee_ID', inplace=True)
display(df.head())
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender Count of Employees")
plt.show()

# %%
from collections.abc import AsyncGenerator
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind='line')
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
X = df[["Years_at_Company", "Satisfaction_Level", "Average_Monthly_Hours"]]
y = df["Salary"]

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\tarun\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.7 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.1/8.7 MB 9.4 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.7 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 11.4 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---- ----------------------------------- 4.7/38.5 MB 22.9 MB/s eta 0:00:02
#    -------- ------------------------------- 8.7/38.5 MB 21.9 MB/s eta 0:00:02
#    --------------- ------------------------ 14.9/38.5 MB 24.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.8/38.5 MB 26.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.6/38.5 MB 27.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.5 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 27.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.5384266 ,  0.07508817, -0.71200429],
#        [ 0.13065848,  0.54062814, -1.61528706],
#        [-0.22128355,  1.34046682,  1.62983995],
#        ...,
#        [ 0.83454254, -0.59343405, -0.47781986],
#        [-0.22128355,  0.91970061, -1.44801247],
#        [ 1.5384266 , -0.0846682 ,  0.09091374]], shape=(800, 3))

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)
X_test
# Out:
# array([[-0.55211437,  0.92280032,  1.6736488 ],
#        [ 0.91044025,  0.34769192, -1.20559596],
#        [ 1.27607891,  0.84953722, -0.88958129],
#        [-0.55211437,  0.67594113, -0.22243921],
#        [ 1.64171757, -1.23365664,  0.93628124],
#        [-0.18647571, -1.34630238, -1.2407087 ],
#        [-0.91775303, -1.01252181, -1.45138515],
#        [ 0.91044025,  1.5667221 , -1.13537048],
#        [-0.18647571, -0.80632703, -0.57356662],
#        [ 1.27607891,  0.78103972,  0.05846271],
#        [ 0.17916294,  0.20674274, -1.03003226],
#        [ 0.91044025, -0.60915155, -0.95980678],
#        [-0.91775303,  1.59660341,  1.11184495],
#        [-0.55211437, -1.31943998,  1.4980851 ],
#        [ 0.91044025,  1.47725511,  1.39274687],
#        [-0.91775303, -1.13195644, -1.48649789],
#        [ 0.5448016 ,  0.45080911, -1.17048322],
#        [-1.64903034, -0.69090789,  0.37447738],
#        [-1.28339168,  0.91728488, -0.67890485],
#        [-1.28339168, -1.2678995 , -0.2926647 ],
#        [-0.18647571, -1.22552541,  0.86605576],
#        [-0.18647571,  1.02825455,  0.37447738],
#        [ 0.17916294, -1.51464127, -1.73228708],
#        [-0.91775303,  1.37432602, -0.71401759],
#        [ 0.91044025, -1.69516954, -1.2407087 ],
#        [ 0.17916294,  0.42234359,  0.26913916],
#        [ 0.17916294, -1.44872604,  1.63853606],
#        [-1.64903034,  1.53103928, -0.08198825],
#        [ 0.91044025,  0.34854731, -1.41627241],
#        [ 0.17916294, -0.28952354, -1.38115967],
#        [ 1.27607891, -1.30442098, -0.78424307],
#        [-1.28339168, -0.4871171 , -1.55672337],
#        [ 0.17916294,  1.05706747,  1.70876154],
#        [ 0.17916294,  1.14072373, -1.73228708],
#        [-1.28339168,  0.89288478, -0.71401759],
#        [-0.55211437, -1.19901469,  0.44470287],
#        [-0.91775303, -0.41858028,  0.40959012],
#        [-1.28339168, -0.62876138, -0.81935581],
#        [-1.28339168, -0.69175645,  1.42785961],
#        [ 1.27607891,  0.40084032, -0.18732647],
#        [-1.28339168, -0.24479145,  0.3042519 ],
#        [ 0.17916294, -0.48090243, -0.92469404],
#        [-1.64903034,  1.25210912,  0.55004109],
#        [ 1.64171757, -0.2392443 ,  0.40959012],
#        [ 0.5448016 , -1.21249826,  0.62026657],
#        [-1.28339168,  1.22035613,  0.44470287],
#        [ 0.17916294, -1.126255  ,  0.37447738],
#        [-0.18647571, -1.72647361,  1.42785961],
#        [ 0.91044025, -1.22778931,  0.62026657],
#        [ 0.5448016 , -0.70672507, -1.69717434],
#        [-1.28339168, -1.13298554,  0.79583028],
#        [ 0.5448016 ,  0.91957587,  0.1286882 ],
#        [ 0.17916294, -0.38415863,  1.39274687],
#        [-1.28339168, -1.39314929,  0.9011685 ],
#        [-0.91775303, -0.41951175,  0.1286882 ],
#        [ 1.64171757, -0.00259291, -0.71401759],
#        [-0.55211437, -1.19373952, -1.10025774],
#        [ 0.17916294, -0.68536175,  0.97139398],
#        [ 0.91044025,  0.52482324,  0.76071753],
#        [ 0.5448016 ,  0.68493899, -0.4682284 ],
#        [ 0.5448016 ,  0.63756563, -0.08198825],
#        [-1.28339168, -0.59764653,  0.58515383],
#        [ 0.91044025,  0.91270478, -0.43311566],
#        [ 1.27607891, -1.18769546, -1.62694886],
#        [ 1.27607891,  0.44482934, -0.95980678],
#        [-0.91775303,  1.22029995, -1.69717434],
#        [ 1.27607891,  0.17939306, -0.74913033],
#        [-1.28339168, -0.51604678, -0.43311566],
#        [-1.28339168, -0.10353583,  1.00650672]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def results(preditions):
  print("Mean absolute error on model is {}", format(mean_absolute_error(y_test,preditions)))
  print("Root mean squared error on model is {}", format(np.sqrt(mean_squared_error(y_test,preditions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictionlr = lr.predict(X_test)

# %%
results(predictionlr)
# Out:
# Mean absolute error on model is {} 17220.459264483357
# Root mean squared error on model is {} 20300.38570591241

# %% [markdown]
# # **Support Vector**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[0.1,0.2,0.5],
    'kernel':['lnear','poly','rbf'],
    'degree':[2,3,4],
}

# %%
gridsvr=GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(X_train,y_train.values.ravel())
# Out:
# c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 135 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'sigmoid', 'linear', 'rbf', 'poly', 'precomputed'} or a callable. Got 'lnear' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\tarun\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [        nan -0.00467139 -0.00467252         nan -0.00467139 -0.00467252
#          nan -0.00467139 -0.00467252         nan -0.00468296 -0.00467252
#          nan -0.00468296 -0.00467252         nan -0.00468296 -0.00467252
#          nan -0.00467039 -0.00467252         nan -0.00467039 -0.00467252
#          nan -0.00467039 -0.00467252         nan -0.00464165 -0.00465375
#          nan -0.00464165 -0.00465379         nan -0.00464165 -0.0046538
#          nan -0.004758   -0.00465375         nan -0.004758   -0.00465379
#          nan -0.004758   -0.0046538          nan -0.0046273  -0.00465375
#          nan -0.00462735 -0.00465379         nan -0.00462749 -0.0046538
#          nan -0.00455753 -0.0042676          nan -0.00455758 -0.00426769
#          nan -0.00455773 -0.00426798         nan -0.00527258 -0.0042676
#          nan -0.00527282 -0.00426769         nan -0.00527353 -0.00426798
#          nan -0.00483058 -0.0042676          nan -0.0048304  -0.00426769
#          nan -0.00482987 -0.00426798]
#   warnings.warn(
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['lnear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.1, 'kernel': 'rbf'}

# %%
predictionsvr = gridsvr.predict(X_test)

# %%
results(predictionsvr)
# Out:
# Mean absolute error on model is {} 17275.48097005503
# Root mean squared error on model is {} 20279.902739246074

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

# %%
param_gridrfr={
    'n_estimators':[2, 3, 4, 5, 6],
    'max_depth' : [5, 10, 15]
}

# %%
gridrfr = GridSearchCV(estimator = rfmodel, param_grid = param_gridrfr, cv = 5)

# %%
gridrfr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
predictionofrfr = gridrfr.predict(X_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is {} 17963.014480329137
# Root mean squared error on model is {} 21214.219258361958

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
